# %%
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# import streamlit as st
# import altair as alt
# import plotly.express as px

# %%
monsters = pd.read_json('../data/creatures/srd_5e_monsters.json')

# %%
monsters.columns
# Out:
# Index(['name', 'meta', 'Armor Class', 'Hit Points', 'Speed', 'STR', 'STR_mod',
#        'DEX', 'DEX_mod', 'CON', 'CON_mod', 'INT', 'INT_mod', 'WIS', 'WIS_mod',
#        'CHA', 'CHA_mod', 'Saving Throws', 'Skills', 'Senses', 'Languages',
#        'Challenge', 'Traits', 'Actions', 'Legendary Actions', 'img_url',
#        'Damage Immunities', 'Condition Immunities', 'Damage Resistances',
#        'Damage Vulnerabilities', 'Reactions'],
#       dtype='object')

# %%
monsters.meta.value_counts()
# Out:
# Large beast, unaligned            28
# Medium beast, unaligned           27
# Medium humanoid, any              22
# Tiny beast, unaligned             18
# Huge beast, unaligned             11
#                                   ..
# Medium undead, any                 1
# Medium elemental, chaotic evil     1
# Huge giant, neutral evil           1
# Small construct, unaligned         1
# Medium construct, neutral          1
# Name: meta, Length: 116, dtype: int64

# %%
sns.histplot(data=monsters, x="meta")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-8a3f725e7493> in <module>
# ----> 1 sns.histplot(data=monsters, x="meta")
#
# AttributeError: module 'seaborn' has no attribute 'histplot'

# %%
diamonds = sns.load_dataset("diamonds")
f, ax = plt.subplots(figsize=(6.5, 6.5))
sns.despine(f, left=True, bottom=True)
clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]
sns.scatterplot(x="speed", y="price",
                hue="clarity", size="depth",
                palette="ch:r=-.2,d=.3_r",
                hue_order=clarity_ranking,
                sizes=(1, 8), linewidth=0,
                data=diamonds, ax=ax)
