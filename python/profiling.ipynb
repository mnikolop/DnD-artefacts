# %%
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

import streamlit as st
# import altair as alt
# import plotly.express as px

# %%
monsters = pd.read_json('../data/creatures/srd_5e_monsters.json')

# %%
print(monsters.columns)
# Out:
# Index(['name', 'meta', 'Armor Class', 'Hit Points', 'Speed', 'STR', 'STR_mod',
#        'DEX', 'DEX_mod', 'CON', 'CON_mod', 'INT', 'INT_mod', 'WIS', 'WIS_mod',
#        'CHA', 'CHA_mod', 'Saving Throws', 'Skills', 'Senses', 'Languages',
#        'Challenge', 'Traits', 'Actions', 'Legendary Actions', 'img_url',
#        'Damage Immunities', 'Condition Immunities', 'Damage Resistances',
#        'Damage Vulnerabilities', 'Reactions'],
#       dtype='object')

# %%
monsters.describe()
# Out:
#               STR         DEX         CON         INT         WIS         CHA
# count  327.000000  327.000000  327.000000  327.000000  327.000000  327.000000
# mean    15.238532   12.645260   15.134557    7.862385   11.709480    9.761468
# std      6.678276    3.196456    4.461863    5.670072    2.897746    5.702597
# min      1.000000    1.000000    8.000000    1.000000    3.000000    1.000000
# 25%     11.000000   10.000000   12.000000    2.000000   10.000000    5.000000
# 50%     16.000000   13.000000   14.000000    7.000000   12.000000    8.000000
# 75%     19.000000   15.000000   18.000000   12.000000   13.000000   14.000000
# max     30.000000   28.000000   30.000000   25.000000   25.000000   30.000000

# %%
monsters = monsters[['name', 'meta', 'Armor Class', 'Hit Points', 'Speed', 'STR', 'STR_mod',
                     'DEX', 'DEX_mod', 'CON', 'CON_mod', 'INT', 'INT_mod', 'WIS', 'WIS_mod',
                     'CHA', 'CHA_mod', 'Saving Throws', 'Skills', 'Senses', 'Languages',
                     'Challenge', 'Damage Immunities', 'Condition Immunities', 'Damage Resistances',
                     'Damage Vulnerabilities', 'Reactions']]

# %%
for i in monsters.columns:
    # print(i)
    data = monsters[i].value_counts().to_frame().reset_index()

    fig, ax = plt.subplots(figsize=(5, 5))
    sns.barplot(data=data.head(5), x='index', y=i)
    ax.tick_params(axis='x', rotation=45)
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# c:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# c:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# c:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# c:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# c:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# c:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """

# %%
monsters.plot(subplots=True, layout=(4,5), figsize=(20, 20))
plt.tight_layout()
plt.show()
